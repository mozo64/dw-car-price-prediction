# %%
1+1
# Out:
# 2

# %%
import mozo2 

import importlib
importlib.reload(mozo2)

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from mozo import compare_and_combine_2, Diff, merge_with_features, num_to_range_categories
import pandas as pd
import numpy as np
np.random.seed(0)

import xgboost as xgb

from scipy import stats
import math 
import datetime 

from sklearn.metrics import r2_score, mean_absolute_error
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from functools import partial
import xgboost as xgb
import lightgbm as lgb
import catboost as ctb
from sklearn.svm import SVC

from sklearn.metrics import r2_score, f1_score, mean_absolute_error, mean_squared_error

from scikitplot.estimators import plot_learning_curve

import time
from datetime import datetime

# %%
## modelowanie

# %%
# import warnings
# warnings.filterwarnings("ignore")

total = pd.read_csv('~/pml7/konkurs/output/newest_total_20201101_07_20.h5.csv')
total.info(verbose=True)

train_30 = pd.read_hdf('output/train_30.h5', 'data') 
test_car_ids = train_30['car_id'].values

train_70 = total[~total['car_id'].isin(test_car_ids) & ~total['price_value'].isna()]
train_30 = total[total['car_id'].isin(test_car_ids)]

print(len(total.index))
print(len(total[~total['price_value'].isna()].index))

print(train_70['price_value'].isna().sum())
print(train_30['price_value'].isna().sum())

train_100 = total[~total['price_value'].isna()]
print(train_100['price_value'].isna().sum())

global_min = total[~total['price_value'].isna()].price_value.min()

test = total[total['price_value'].isna()]
train = total[~total['price_value'].isna()]
# Out:
# /home/conda/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3,86,161) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160616 entries, 0 to 160615
# Data columns (total 218 columns):
#  #   Column                                                  Dtype
# ---  ------                                                  -----
#  0   breadcrumb                                              object
#  1   created_at                                              object
#  2   price_currency                                          object
#  3   price_details                                           object
#  4   price_value                                             float64
#  5   seller_address                                          object
#  6   seller_name                                             object
#  7   seller_type                                             object
#  8   feature_czujniki_parkowania_przednie                    bool
#  9   feature_poduszka_powietrzna_chroniąca_kolana            bool
#  10  feature_kurtyny_powietrzne                              bool
#  11  feature_klimatyzacja_dwustrefowa                        bool
#  12  feature_światła_led                                     bool
#  13  feature_czujnik_zmierzchu                               bool
#  14  feature_elektrycznie_ustawiane_lusterka                 bool
#  15  feature_asr__kontrola_trakcji_                          bool
#  16  feature_poduszka_powietrzna_kierowcy                    bool
#  17  feature_cd                                              bool
#  18  feature_elektryczne_szyby_przednie                      bool
#  19  feature_poduszka_powietrzna_pasażera                    bool
#  20  feature_system_start_stop                               bool
#  21  feature_światła_do_jazdy_dziennej                       bool
#  22  feature_komputer_pokładowy                              bool
#  23  feature_elektryczne_szyby_tylne                         bool
#  24  feature_klimatyzacja_manualna                           bool
#  25  feature_tapicerka_welurowa                              bool
#  26  feature_czujnik_deszczu                                 bool
#  27  feature_światła_przeciwmgielne                          bool
#  28  feature_ogrzewanie_postojowe                            bool
#  29  feature_radio_niefabryczne                              bool
#  30  feature_regulowane_zawieszenie                          bool
#  31  feature_ogranicznik_prędkości                           bool
#  32  feature_zmieniarka_cd                                   bool
#  33  feature_szyberdach                                      bool
#  34  feature_isofix                                          bool
#  35  feature_asystent_pasa_ruchu                             bool
#  36  feature_alufelgi                                        bool
#  37  feature_bluetooth                                       bool
#  38  feature_nawigacja_gps                                   bool
#  39  feature_asystent_parkowania                             bool
#  40  feature_wspomaganie_kierownicy                          bool
#  41  feature_podgrzewana_przednia_szyba                      bool
#  42  feature_przyciemniane_szyby                             bool
#  43  feature_elektrycznie_ustawiane_fotele                   bool
#  44  feature_klimatyzacja_czterostrefowa                     bool
#  45  feature_tuner_tv                                        bool
#  46  feature_poduszki_boczne_przednie                        bool
#  47  feature_tempomat_aktywny                                bool
#  48  feature_klimatyzacja_automatyczna                       bool
#  49  feature_poduszki_boczne_tylne                           bool
#  50  feature_radio_fabryczne                                 bool
#  51  feature_odtwarzacz_dvd                                  bool
#  52  feature_czujniki_parkowania_tylne                       bool
#  53  feature_łopatki_zmiany_biegów                           bool
#  54  feature_centralny_zamek                                 bool
#  55  feature_dach_panoramiczny                               bool
#  56  feature_kamera_cofania                                  bool
#  57  feature_immobilizer                                     bool
#  58  feature_czujnik_martwego_pola                           bool
#  59  feature_gniazdo_sd                                      bool
#  60  feature_podgrzewane_lusterka_boczne                     bool
#  61  feature_podgrzewane_przednie_siedzenia                  bool
#  62  feature_hak                                             bool
#  63  feature_abs                                             bool
#  64  feature_wielofunkcyjna_kierownica                       bool
#  65  feature_światła_xenonowe                                bool
#  66  feature_gniazdo_usb                                     bool
#  67  feature_tapicerka_skórzana                              bool
#  68  feature_gniazdo_aux                                     bool
#  69  feature_esp__stabilizacja_toru_jazdy_                   bool
#  70  feature_alarm                                           bool
#  71  feature_podgrzewane_tylne_siedzenia                     bool
#  72  feature_mp3                                             bool
#  73  feature_tempomat                                        bool
#  74  feature_hud__wyświetlacz_przezierny_                    bool
#  75  feature_elektrochromatyczne_lusterko_wsteczne           bool
#  76  feature_relingi_dachowe                                 bool
#  77  feature_elektrochromatyczne_lusterka_boczne             bool
#  78  param_faktura_vat                                       bool
#  79  param_vin                                               object
#  80  param_homologacja_ciężarowa                             bool
#  81  param_vat_marża                                         bool
#  82  param_kategoria                                         object
#  83  param_zarejestrowany_jako_zabytek                       bool
#  84  param_wartość_wykupu                                    object
#  85  param_vat_discount                                      bool
#  86  param_liczba_pozostałych_rat                            object
#  87  param_oferta_od                                         object
#  88  param_opłata_początkowa                                 object
#  89  param_kierownica_po_prawej__anglik_                     bool
#  90  param_vat_free                                          bool
#  91  param_tuning                                            bool
#  92  param_stan                                              object
#  93  param_matowy                                            bool
#  94  car_id                                                  int64
#  95  created_at_unix                                         float64
#  96  created_at_unix_na_mean                                 float64
#  97  pln_to_eur                                              float64
#  98  price_value_pln                                         float64
#  99  price_value_pln_log_transl                              float64
#  100 latitude                                                float64
#  101 latitude_na_mean                                        float64
#  102 longitude                                               float64
#  103 longitude_na_mean                                       float64
#  104 param_liczba_miejsc                                     float64
#  105 param_marka_pojazdu                                     object
#  106 param_model_pojazdu                                     object
#  107 param_kod_silnika                                       object
#  108 param_liczba_drzwi                                      float64
#  109 param_pierwsza_rejestracja                              object
#  110 param_kraj_pochodzenia                                  object
#  111 param_skrzynia_biegów                                   object
#  112 param_serwisowany_w_aso                                 bool
#  113 param_kolor                                             object
#  114 param_pierwszy_właściciel                               bool
#  115 param_bezwypadkowy                                      bool
#  116 param_zarejestrowany_w_polsce                           bool
#  117 param_moc                                               int64
#  118 param_rok_produkcji                                     int64
#  119 param_napęd                                             object
#  120 param_pojemność_skokowa                                 int64
#  121 param_rodzaj_paliwa                                     object
#  122 param_typ                                               object
#  123 param_emisja_co2                                        object
#  124 param_filtr_cząstek_stałych                             bool
#  125 param_uszkodzony                                        bool
#  126 param_przebieg                                          int64
#  127 param_perłowy                                           bool
#  128 param_metalik                                           bool
#  129 param_leasing                                           bool
#  130 param_możliwość_finansowania                            bool
#  131 param_miesięczna_rata                                   object
#  132 param_wersja                                            object
#  133 param_akryl__niemetalizowany_                           bool
#  134 param_pierwsza_rejestracja_date                         float64
#  135 price_value_log                                         float64
#  136 price_currency_pln                                      bool
#  137 new_seller_address_cat                                  int64
#  138 new_seller_name_cat                                     int64
#  139 new_seller_type_cat                                     int64
#  140 new_param_vin_cat                                       int64
#  141 new_param_kategoria_cat                                 int64
#  142 new_param_wartość_wykupu_cat                            int64
#  143 new_param_liczba_pozostałych_rat_cat                    int64
#  144 new_param_oferta_od_cat                                 int64
#  145 new_param_opłata_początkowa_cat                         int64
#  146 new_param_stan_cat                                      int64
#  147 new_param_marka_pojazdu_cat                             int64
#  148 new_param_model_pojazdu_cat                             int64
#  149 new_param_kod_silnika_cat                               int64
#  150 new_param_pierwsza_rejestracja_cat                      int64
#  151 new_param_kraj_pochodzenia_cat                          int64
#  152 new_param_skrzynia_biegów_cat                           int64
#  153 new_param_kolor_cat                                     int64
#  154 new_param_napęd_cat                                     int64
#  155 new_param_rodzaj_paliwa_cat                             int64
#  156 new_param_typ_cat                                       int64
#  157 new_param_emisja_co2_cat                                int64
#  158 new_param_miesięczna_rata_cat                           int64
#  159 new_param_wersja_cat                                    int64
#  160 new_cat_seller_address                                  float64
#  161 new_cat_price_value                                     object
#  162 model_8790                                              float64
#  163 param_rodzaj_paliwa_2                                   object
#  164 encoded_param_rodzaj_paliwa_2                           int64
#  165 param_skrzynia_biegów_2                                 object
#  166 encoded_param_skrzynia_biegów_2                         int64
#  167 param_napęd_2                                           object
#  168 encoded_param_napęd_2                                   int64
#  169 param_kolor_2                                           object
#  170 encoded_param_kolor_2                                   int64
#  171 param_vin_len                                           int64
#  172 vin_where                                               object
#  173 vin_flex_fuel                                           object
#  174 vin_portrait                                            object
#  175 vin_security                                            object
#  176 vin_model                                               object
#  177 vin_plant                                               object
#  178 param_typ_2                                             object
#  179 encoded_param_typ_2                                     int64
#  180 new_vin_where_cat                                       int64
#  181 new_vin_flex_fuel_cat                                   int64
#  182 new_vin_portrait_cat                                    int64
#  183 new_vin_security_cat                                    int64
#  184 new_vin_model_cat                                       int64
#  185 new_vin_plant_cat                                       int64
#  186 seller_wojewodzctwo                                     object
#  187 new_seller_wojewodzctwo_cat                             int64
#  188 param_wartość_wykupu_2                                  float64
#  189 param_liczba_pozostałych_rat_2                          float64
#  190 param_opłata_początkowa_2                               float64
#  191 param_emisja_co2_2                                      int64
#  192 param_miesięczna_rata_2                                 float64
#  193 param_pierwsza_rejestracja_date_na                      float64
#  194 model_XGBRegressor_5856_36229_                          float64
#  195 param_liczba_miejsc_2                                   float64
#  196 model_XGBRegressor_3293_22097_                          float64
#  197 model_RandomForestRegressor_7089_27166_feats2           float64
#  198 model_XGBRegressor_3422_09438_start_vars_train_100      float64
#  199 seller_miasto                                           object
#  200 encoded_seller_miasto_297                               int64
#  201 encoded_seller_miasto_perc_40                           object
#  202 param_moc_norm                                          float64
#  203 param_pojemność_skokowa_norm                            float64
#  204 ogloszenie_rok                                          float64
#  205 ogloszenie_miesiac                                      float64
#  206 ogloszenie_dzien_tyg                                    float64
#  207 ogloszenie_godzina                                      float64
#  208 ogloszenie_dni_wisi                                     float64
#  209 param_pierwsza_rejestracja_ten_rok                      int64
#  210 param_pierwsza_rejestracja_poprzedni_rok                int64
#  211 param_pierwsza_rejestracja_10_lat                       int64
#  212 param_rok_produkcji_ten_rok                             int64
#  213 param_rok_produkcji_poprzedni_rok                       int64
#  214 param_rok_produkcji_10_lat                              int64
#  215 param_ile_lat_temu_produkcja                            int64
#  216 model_XGBRegressor_2608_37590_po_hiperopcie             float64
#  217 model_XGBRegressor_2195_24982_po_hiperopcie_caly_train  float64
# dtypes: bool(91), float64(35), int64(50), object(42)
# memory usage: 169.6+ MB
# 160616
# 106494
# 0
# 0
# 0

# %%
start_vars = np.sort([
# 'created_at_unix', 'encoded_param_napęd_2', 'encoded_param_rodzaj_paliwa_2', 'encoded_param_skrzynia_biegów_2', 'feature_abs', 'feature_alufelgi', 'feature_asr__kontrola_trakcji_', 'feature_asystent_parkowania', 'feature_bluetooth', 'feature_cd', 'feature_czujniki_parkowania_przednie', 'feature_elektryczne_szyby_tylne', 'feature_elektrycznie_ustawiane_lusterka', 'feature_esp__stabilizacja_toru_jazdy_', 'feature_gniazdo_sd', 'feature_klimatyzacja_automatyczna', 'feature_klimatyzacja_dwustrefowa', 'feature_klimatyzacja_manualna', 'feature_radio_fabryczne', 'feature_tempomat', 'feature_światła_do_jazdy_dziennej', 'feature_światła_led', 'feature_światła_xenonowe', 'latitude', 'longitude', 'model_XGBRegressor_5856_36229_', 'new_param_kod_silnika_cat', 'new_param_liczba_pozostałych_rat_cat', 'new_param_marka_pojazdu_cat', 'new_param_model_pojazdu_cat', 'new_param_napęd_cat', 'new_param_oferta_od_cat', 'new_param_vin_cat', 'new_param_wersja_cat', 'new_seller_name_cat', 'param_bezwypadkowy', 'param_ile_lat_temu_produkcja', 'param_kierownica_po_prawej__anglik_', 'param_leasing', 'param_liczba_miejsc_2', 'param_moc', 'param_pierwsza_rejestracja_date_na', 'param_pojemność_skokowa', 'param_przebieg', 'param_rok_produkcji', 'param_serwisowany_w_aso', 'param_tuning', 'param_uszkodzony', 'param_wartość_wykupu_2', 'param_zarejestrowany_w_polsce', 'price_currency_pln'
# 'created_at_unix', 'encoded_param_rodzaj_paliwa_2', 'encoded_param_typ_2', 'feature_abs', 'feature_asr__kontrola_trakcji_', 'feature_bluetooth', 'feature_cd', 'feature_czujniki_parkowania_przednie', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_gniazdo_sd', 'feature_hud__wyświetlacz_przezierny_', 'feature_isofix', 'feature_klimatyzacja_automatyczna', 'feature_klimatyzacja_manualna', 'feature_ogrzewanie_postojowe', 'feature_podgrzewane_tylne_siedzenia', 'feature_relingi_dachowe', 'feature_tapicerka_skórzana', 'feature_tapicerka_welurowa', 'feature_tempomat', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'feature_światła_xenonowe', 'latitude_na_mean', 'longitude', 'longitude_na_mean', 'model_8790', 'new_param_kolor_cat', 'new_param_liczba_pozostałych_rat_cat', 'new_param_marka_pojazdu_cat', 'new_param_oferta_od_cat', 'new_param_opłata_początkowa_cat', 'new_param_rodzaj_paliwa_cat', 'new_param_wersja_cat', 'new_seller_name_cat', 'new_vin_flex_fuel_cat', 'new_vin_model_cat', 'new_vin_security_cat', 'param_bezwypadkowy', 'param_homologacja_ciężarowa', 'param_ile_lat_temu_produkcja', 'param_leasing', 'param_liczba_miejsc_2', 'param_liczba_pozostałych_rat_2', 'param_matowy', 'param_przebieg', 'param_rok_produkcji', 'param_tuning', 'param_uszkodzony', 'param_wartość_wykupu_2'
# 'model_8790', 'feature_bluetooth', 'created_at_unix', 'encoded_param_rodzaj_paliwa_2', 'encoded_param_typ_2', 'feature_asr__kontrola_trakcji_', 'feature_asystent_parkowania', 'feature_cd', 'feature_centralny_zamek', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_gniazdo_sd', 'feature_isofix', 'feature_klimatyzacja_automatyczna', 'feature_klimatyzacja_manualna', 'feature_ogrzewanie_postojowe', 'feature_podgrzewane_tylne_siedzenia', 'feature_relingi_dachowe', 'feature_tapicerka_skórzana', 'feature_tempomat', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'longitude', 'latitude', 'new_param_kolor_cat', 'new_param_liczba_pozostałych_rat_cat', 'new_param_marka_pojazdu_cat', 'new_param_oferta_od_cat', 'new_param_opłata_początkowa_cat', 'new_param_wersja_cat', 'new_seller_name_cat', 'new_vin_flex_fuel_cat', 'new_vin_model_cat', 'new_vin_portrait_cat', 'new_vin_security_cat', 'ogloszenie_rok', 'param_bezwypadkowy', 'param_homologacja_ciężarowa', 'param_ile_lat_temu_produkcja', 'param_leasing', 'param_liczba_miejsc_2', 'param_liczba_pozostałych_rat_2', 'param_matowy', 'param_moc', 'param_perłowy', 'param_pierwsza_rejestracja_10_lat', 'param_przebieg', 'param_rok_produkcji', 'param_tuning', 'param_uszkodzony', 'param_vin_len'
# 'encoded_param_rodzaj_paliwa_2', 'feature_abs', 'feature_asr__kontrola_trakcji_', 'feature_bluetooth', 'feature_centralny_zamek', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_gniazdo_sd', 'feature_immobilizer', 'feature_isofix', 'feature_klimatyzacja_automatyczna', 'feature_klimatyzacja_manualna', 'feature_komputer_pokładowy', 'feature_ogrzewanie_postojowe', 'feature_podgrzewane_tylne_siedzenia', 'feature_poduszka_powietrzna_kierowcy', 'feature_radio_fabryczne', 'feature_szyberdach', 'feature_tapicerka_skórzana', 'feature_tempomat', 'feature_zmieniarka_cd', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'model_8790', 'new_param_kolor_cat', 'new_param_liczba_pozostałych_rat_cat', 'new_param_marka_pojazdu_cat', 'new_param_model_pojazdu_cat', 'new_param_oferta_od_cat', 'new_param_opłata_początkowa_cat', 'new_param_wersja_cat', 'new_seller_name_cat', 'new_vin_flex_fuel_cat', 'new_vin_model_cat', 'new_vin_portrait_cat', 'new_vin_security_cat', 'ogloszenie_rok', 'param_bezwypadkowy', 'param_filtr_cząstek_stałych', 'param_homologacja_ciężarowa', 'param_ile_lat_temu_produkcja', 'param_liczba_pozostałych_rat_2', 'param_matowy', 'param_metalik', 'param_moc', 'param_perłowy', 'param_pierwsza_rejestracja_10_lat', 'param_pierwsza_rejestracja_ten_rok', 'param_przebieg', 'param_serwisowany_w_aso', 'param_tuning'
# 'encoded_param_rodzaj_paliwa_2', 'feature_abs', 'feature_bluetooth', 'feature_centralny_zamek', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_gniazdo_sd', 'feature_immobilizer', 'feature_isofix', 'feature_klimatyzacja_automatyczna', 'feature_klimatyzacja_manualna', 'feature_komputer_pokładowy', 'feature_ogrzewanie_postojowe', 'feature_podgrzewane_tylne_siedzenia', 'feature_poduszka_powietrzna_kierowcy', 'feature_radio_fabryczne', 'feature_szyberdach', 'feature_tapicerka_skórzana', 'feature_tempomat', 'feature_wielofunkcyjna_kierownica', 'feature_zmieniarka_cd', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'model_8790', 'new_param_kategoria_cat', 'new_param_kolor_cat', 'new_param_liczba_pozostałych_rat_cat', 'new_param_marka_pojazdu_cat', 'new_param_model_pojazdu_cat', 'new_param_oferta_od_cat', 'new_param_opłata_początkowa_cat', 'new_seller_name_cat', 'new_vin_flex_fuel_cat', 'new_vin_model_cat', 'new_vin_portrait_cat', 'new_vin_security_cat', 'ogloszenie_rok', 'param_faktura_vat', 'param_filtr_cząstek_stałych', 'param_homologacja_ciężarowa', 'param_ile_lat_temu_produkcja', 'param_liczba_pozostałych_rat_2', 'param_matowy', 'param_metalik', 'param_moc', 'param_perłowy', 'param_pierwsza_rejestracja_10_lat', 'param_pierwsza_rejestracja_ten_rok', 'param_przebieg', 'param_serwisowany_w_aso', 'param_tuning'
# 'encoded_param_napęd_2', 'encoded_param_rodzaj_paliwa_2', 'feature_asystent_parkowania', 'feature_centralny_zamek', 'feature_czujnik_deszczu', 'feature_elektrochromatyczne_lusterko_wsteczne', 'feature_elektryczne_szyby_tylne', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_hud__wyświetlacz_przezierny_', 'feature_klimatyzacja_manualna', 'feature_mp3', 'feature_nawigacja_gps', 'feature_odtwarzacz_dvd', 'feature_ogranicznik_prędkości', 'feature_ogrzewanie_postojowe', 'feature_podgrzewana_przednia_szyba', 'feature_podgrzewane_tylne_siedzenia', 'feature_poduszka_powietrzna_kierowcy', 'feature_poduszki_boczne_przednie', 'feature_poduszki_boczne_tylne', 'feature_przyciemniane_szyby', 'feature_radio_fabryczne', 'feature_regulowane_zawieszenie', 'feature_tapicerka_skórzana', 'feature_wielofunkcyjna_kierownica', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'feature_światła_xenonowe', 'model_8790', 'new_param_emisja_co2_cat', 'new_param_kategoria_cat', 'new_param_rodzaj_paliwa_cat', 'new_param_skrzynia_biegów_cat', 'new_param_stan_cat', 'new_param_wersja_cat', 'new_seller_type_cat', 'new_seller_wojewodzctwo_cat', 'new_vin_portrait_cat', 'new_vin_security_cat', 'param_bezwypadkowy', 'param_faktura_vat', 'param_filtr_cząstek_stałych', 'param_liczba_miejsc_2', 'param_liczba_pozostałych_rat_2', 'param_miesięczna_rata_2', 'param_pierwsza_rejestracja_10_lat', 'param_pierwsza_rejestracja_date_na', 'param_przebieg', 'param_serwisowany_w_aso', 'param_vin_len'
'encoded_param_napęd_2', 'encoded_param_rodzaj_paliwa_2', 'feature_abs', 'feature_asystent_parkowania', 'feature_centralny_zamek', 'feature_czujnik_deszczu', 'feature_elektrochromatyczne_lusterko_wsteczne', 'feature_elektryczne_szyby_tylne', 'feature_elektrycznie_ustawiane_fotele', 'feature_elektrycznie_ustawiane_lusterka', 'feature_hud__wyświetlacz_przezierny_', 'feature_klimatyzacja_manualna', 'feature_mp3', 'feature_nawigacja_gps', 'feature_odtwarzacz_dvd', 'feature_ogranicznik_prędkości', 'feature_ogrzewanie_postojowe', 'feature_podgrzewana_przednia_szyba', 'feature_podgrzewane_tylne_siedzenia', 'feature_poduszka_powietrzna_kierowcy', 'feature_poduszki_boczne_przednie', 'feature_poduszki_boczne_tylne', 'feature_przyciemniane_szyby', 'feature_radio_fabryczne', 'feature_regulowane_zawieszenie', 'feature_tapicerka_skórzana', 'feature_wielofunkcyjna_kierownica', 'feature_światła_led', 'feature_światła_przeciwmgielne', 'feature_światła_xenonowe', 'model_8790', 'new_param_emisja_co2_cat', 'new_param_kategoria_cat', 'new_param_rodzaj_paliwa_cat', 'new_param_skrzynia_biegów_cat', 'new_param_stan_cat', 'new_param_wersja_cat', 'new_seller_type_cat', 'new_seller_wojewodzctwo_cat', 'new_vin_portrait_cat', 'new_vin_security_cat', 'param_bezwypadkowy', 'param_faktura_vat', 'param_filtr_cząstek_stałych', 'param_liczba_miejsc_2', 'param_liczba_pozostałych_rat_2', 'param_miesięczna_rata_2', 'param_pierwsza_rejestracja_10_lat', 'param_pierwsza_rejestracja_date_na', 'param_przebieg', 'param_serwisowany_w_aso', 'param_vin_len'
])

# 'model_8790' = car_price_log_Vladimir_categories_xgb.csv; 5637.56722; "opis": "Vladimir z kategorialnymi mae na train_30"

black_list = ['car_id', 'price_details', 'price_value', 'price_value_log', 'price_value_pln', 'price_value_pln_log_transl', 'new_cat_price_value',
#               *[x for x in total.columns if x.startswith('model_')],
              'model_XGBRegressor_2195_24982_po_hiperopcie_caly_train', #train_100, przeuczony
              'model_XGBRegressor_3293_22097_', #train_100
              'longitude_na_mean', 'latitude_na_mean', #gorsze w xbfir
              *total.columns[total.isnull().any()],
             ]

feats3 = total.select_dtypes(include=[np.number, np.bool]).columns
feats3 = [x for x in feats3 if x not in black_list]
feats3 = np.sort(feats3)

print(total[start_vars].info(verbose=True))

print(total[feats3].info(verbose=True))
print(total[feats3].columns[total[feats3].isnull().any()])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160616 entries, 0 to 160615
# Data columns (total 52 columns):
#  #   Column                                         Non-Null Count   Dtype
# ---  ------                                         --------------   -----
#  0   encoded_param_napęd_2                          160616 non-null  int64
#  1   encoded_param_rodzaj_paliwa_2                  160616 non-null  int64
#  2   feature_abs                                    160616 non-null  bool
#  3   feature_asystent_parkowania                    160616 non-null  bool
#  4   feature_centralny_zamek                        160616 non-null  bool
#  5   feature_czujnik_deszczu                        160616 non-null  bool
#  6   feature_elektrochromatyczne_lusterko_wsteczne  160616 non-null  bool
#  7   feature_elektryczne_szyby_tylne                160616 non-null  bool
#  8   feature_elektrycznie_ustawiane_fotele          160616 non-null  bool
#  9   feature_elektrycznie_ustawiane_lusterka        160616 non-null  bool
#  10  feature_hud__wyświetlacz_przezierny_           160616 non-null  bool
#  11  feature_klimatyzacja_manualna                  160616 non-null  bool
#  12  feature_mp3                                    160616 non-null  bool
#  13  feature_nawigacja_gps                          160616 non-null  bool
#  14  feature_odtwarzacz_dvd                         160616 non-null  bool
#  15  feature_ogranicznik_prędkości                  160616 non-null  bool
#  16  feature_ogrzewanie_postojowe                   160616 non-null  bool
#  17  feature_podgrzewana_przednia_szyba             160616 non-null  bool
#  18  feature_podgrzewane_tylne_siedzenia            160616 non-null  bool
#  19  feature_poduszka_powietrzna_kierowcy           160616 non-null  bool
#  20  feature_poduszki_boczne_przednie               160616 non-null  bool
#  21  feature_poduszki_boczne_tylne                  160616 non-null  bool
#  22  feature_przyciemniane_szyby                    160616 non-null  bool
#  23  feature_radio_fabryczne                        160616 non-null  bool
#  24  feature_regulowane_zawieszenie                 160616 non-null  bool
#  25  feature_tapicerka_skórzana                     160616 non-null  bool
#  26  feature_wielofunkcyjna_kierownica              160616 non-null  bool
#  27  feature_światła_led                            160616 non-null  bool
#  28  feature_światła_przeciwmgielne                 160616 non-null  bool
#  29  feature_światła_xenonowe                       160616 non-null  bool
#  30  model_8790                                     160616 non-null  float64
#  31  new_param_emisja_co2_cat                       160616 non-null  int64
#  32  new_param_kategoria_cat                        160616 non-null  int64
#  33  new_param_rodzaj_paliwa_cat                    160616 non-null  int64
#  34  new_param_skrzynia_biegów_cat                  160616 non-null  int64
#  35  new_param_stan_cat                             160616 non-null  int64
#  36  new_param_wersja_cat                           160616 non-null  int64
#  37  new_seller_type_cat                            160616 non-null  int64
#  38  new_seller_wojewodzctwo_cat                    160616 non-null  int64
#  39  new_vin_portrait_cat                           160616 non-null  int64
#  40  new_vin_security_cat                           160616 non-null  int64
#  41  param_bezwypadkowy                             160616 non-null  bool
#  42  param_faktura_vat                              160616 non-null  bool
#  43  param_filtr_cząstek_stałych                    160616 non-null  bool
#  44  param_liczba_miejsc_2                          160616 non-null  float64
#  45  param_liczba_pozostałych_rat_2                 160616 non-null  float64
#  46  param_miesięczna_rata_2                        160616 non-null  float64
#  47  param_pierwsza_rejestracja_10_lat              160616 non-null  int64
#  48  param_pierwsza_rejestracja_date_na             160616 non-null  float64
#  49  param_przebieg                                 160616 non-null  int64
#  50  param_serwisowany_w_aso                        160616 non-null  bool
#  51  param_vin_len                                  160616 non-null  int64
# dtypes: bool(32), float64(5), int64(15)
# memory usage: 29.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160616 entries, 0 to 160615
# Data columns (total 163 columns):
#  #   Column                                              Dtype
# ---  ------                                              -----
#  0   created_at_unix                                     float64
#  1   created_at_unix_na_mean                             float64
#  2   encoded_param_kolor_2                               int64
#  3   encoded_param_napęd_2                               int64
#  4   encoded_param_rodzaj_paliwa_2                       int64
#  5   encoded_param_skrzynia_biegów_2                     int64
#  6   encoded_param_typ_2                                 int64
#  7   encoded_seller_miasto_297                           int64
#  8   feature_abs                                         bool
#  9   feature_alarm                                       bool
#  10  feature_alufelgi                                    bool
#  11  feature_asr__kontrola_trakcji_                      bool
#  12  feature_asystent_parkowania                         bool
#  13  feature_asystent_pasa_ruchu                         bool
#  14  feature_bluetooth                                   bool
#  15  feature_cd                                          bool
#  16  feature_centralny_zamek                             bool
#  17  feature_czujnik_deszczu                             bool
#  18  feature_czujnik_martwego_pola                       bool
#  19  feature_czujnik_zmierzchu                           bool
#  20  feature_czujniki_parkowania_przednie                bool
#  21  feature_czujniki_parkowania_tylne                   bool
#  22  feature_dach_panoramiczny                           bool
#  23  feature_elektrochromatyczne_lusterka_boczne         bool
#  24  feature_elektrochromatyczne_lusterko_wsteczne       bool
#  25  feature_elektryczne_szyby_przednie                  bool
#  26  feature_elektryczne_szyby_tylne                     bool
#  27  feature_elektrycznie_ustawiane_fotele               bool
#  28  feature_elektrycznie_ustawiane_lusterka             bool
#  29  feature_esp__stabilizacja_toru_jazdy_               bool
#  30  feature_gniazdo_aux                                 bool
#  31  feature_gniazdo_sd                                  bool
#  32  feature_gniazdo_usb                                 bool
#  33  feature_hak                                         bool
#  34  feature_hud__wyświetlacz_przezierny_                bool
#  35  feature_immobilizer                                 bool
#  36  feature_isofix                                      bool
#  37  feature_kamera_cofania                              bool
#  38  feature_klimatyzacja_automatyczna                   bool
#  39  feature_klimatyzacja_czterostrefowa                 bool
#  40  feature_klimatyzacja_dwustrefowa                    bool
#  41  feature_klimatyzacja_manualna                       bool
#  42  feature_komputer_pokładowy                          bool
#  43  feature_kurtyny_powietrzne                          bool
#  44  feature_mp3                                         bool
#  45  feature_nawigacja_gps                               bool
#  46  feature_odtwarzacz_dvd                              bool
#  47  feature_ogranicznik_prędkości                       bool
#  48  feature_ogrzewanie_postojowe                        bool
#  49  feature_podgrzewana_przednia_szyba                  bool
#  50  feature_podgrzewane_lusterka_boczne                 bool
#  51  feature_podgrzewane_przednie_siedzenia              bool
#  52  feature_podgrzewane_tylne_siedzenia                 bool
#  53  feature_poduszka_powietrzna_chroniąca_kolana        bool
#  54  feature_poduszka_powietrzna_kierowcy                bool
#  55  feature_poduszka_powietrzna_pasażera                bool
#  56  feature_poduszki_boczne_przednie                    bool
#  57  feature_poduszki_boczne_tylne                       bool
#  58  feature_przyciemniane_szyby                         bool
#  59  feature_radio_fabryczne                             bool
#  60  feature_radio_niefabryczne                          bool
#  61  feature_regulowane_zawieszenie                      bool
#  62  feature_relingi_dachowe                             bool
#  63  feature_system_start_stop                           bool
#  64  feature_szyberdach                                  bool
#  65  feature_tapicerka_skórzana                          bool
#  66  feature_tapicerka_welurowa                          bool
#  67  feature_tempomat                                    bool
#  68  feature_tempomat_aktywny                            bool
#  69  feature_tuner_tv                                    bool
#  70  feature_wielofunkcyjna_kierownica                   bool
#  71  feature_wspomaganie_kierownicy                      bool
#  72  feature_zmieniarka_cd                               bool
#  73  feature_łopatki_zmiany_biegów                       bool
#  74  feature_światła_do_jazdy_dziennej                   bool
#  75  feature_światła_led                                 bool
#  76  feature_światła_przeciwmgielne                      bool
#  77  feature_światła_xenonowe                            bool
#  78  latitude                                            float64
#  79  longitude                                           float64
#  80  model_8790                                          float64
#  81  model_RandomForestRegressor_7089_27166_feats2       float64
#  82  model_XGBRegressor_2608_37590_po_hiperopcie         float64
#  83  model_XGBRegressor_3422_09438_start_vars_train_100  float64
#  84  model_XGBRegressor_5856_36229_                      float64
#  85  new_cat_seller_address                              float64
#  86  new_param_emisja_co2_cat                            int64
#  87  new_param_kategoria_cat                             int64
#  88  new_param_kod_silnika_cat                           int64
#  89  new_param_kolor_cat                                 int64
#  90  new_param_kraj_pochodzenia_cat                      int64
#  91  new_param_liczba_pozostałych_rat_cat                int64
#  92  new_param_marka_pojazdu_cat                         int64
#  93  new_param_miesięczna_rata_cat                       int64
#  94  new_param_model_pojazdu_cat                         int64
#  95  new_param_napęd_cat                                 int64
#  96  new_param_oferta_od_cat                             int64
#  97  new_param_opłata_początkowa_cat                     int64
#  98  new_param_pierwsza_rejestracja_cat                  int64
#  99  new_param_rodzaj_paliwa_cat                         int64
#  100 new_param_skrzynia_biegów_cat                       int64
#  101 new_param_stan_cat                                  int64
#  102 new_param_typ_cat                                   int64
#  103 new_param_vin_cat                                   int64
#  104 new_param_wartość_wykupu_cat                        int64
#  105 new_param_wersja_cat                                int64
#  106 new_seller_address_cat                              int64
#  107 new_seller_name_cat                                 int64
#  108 new_seller_type_cat                                 int64
#  109 new_seller_wojewodzctwo_cat                         int64
#  110 new_vin_flex_fuel_cat                               int64
#  111 new_vin_model_cat                                   int64
#  112 new_vin_plant_cat                                   int64
#  113 new_vin_portrait_cat                                int64
#  114 new_vin_security_cat                                int64
#  115 new_vin_where_cat                                   int64
#  116 ogloszenie_dni_wisi                                 float64
#  117 ogloszenie_dzien_tyg                                float64
#  118 ogloszenie_godzina                                  float64
#  119 ogloszenie_miesiac                                  float64
#  120 ogloszenie_rok                                      float64
#  121 param_akryl__niemetalizowany_                       bool
#  122 param_bezwypadkowy                                  bool
#  123 param_emisja_co2_2                                  int64
#  124 param_faktura_vat                                   bool
#  125 param_filtr_cząstek_stałych                         bool
#  126 param_homologacja_ciężarowa                         bool
#  127 param_ile_lat_temu_produkcja                        int64
#  128 param_kierownica_po_prawej__anglik_                 bool
#  129 param_leasing                                       bool
#  130 param_liczba_drzwi                                  float64
#  131 param_liczba_miejsc_2                               float64
#  132 param_liczba_pozostałych_rat_2                      float64
#  133 param_matowy                                        bool
#  134 param_metalik                                       bool
#  135 param_miesięczna_rata_2                             float64
#  136 param_moc                                           int64
#  137 param_możliwość_finansowania                        bool
#  138 param_opłata_początkowa_2                           float64
#  139 param_perłowy                                       bool
#  140 param_pierwsza_rejestracja_10_lat                   int64
#  141 param_pierwsza_rejestracja_date_na                  float64
#  142 param_pierwsza_rejestracja_poprzedni_rok            int64
#  143 param_pierwsza_rejestracja_ten_rok                  int64
#  144 param_pierwszy_właściciel                           bool
#  145 param_pojemność_skokowa                             int64
#  146 param_przebieg                                      int64
#  147 param_rok_produkcji                                 int64
#  148 param_rok_produkcji_10_lat                          int64
#  149 param_rok_produkcji_poprzedni_rok                   int64
#  150 param_rok_produkcji_ten_rok                         int64
#  151 param_serwisowany_w_aso                             bool
#  152 param_tuning                                        bool
#  153 param_uszkodzony                                    bool
#  154 param_vat_discount                                  bool
#  155 param_vat_free                                      bool
#  156 param_vat_marża                                     bool
#  157 param_vin_len                                       int64
#  158 param_wartość_wykupu_2                              float64
#  159 param_zarejestrowany_jako_zabytek                   bool
#  160 param_zarejestrowany_w_polsce                       bool
#  161 pln_to_eur                                          float64
#  162 price_currency_pln                                  bool
# dtypes: bool(91), float64(23), int64(49)
# memory usage: 102.2 MB
# None
# Index([], dtype='object')

# %%
import contextlib
import warnings
warnings.filterwarnings("ignore")
import json

params = {    
    'n_jobs': 12, 

    'n_estimators': 90, 
    'learning_rate': 0.1, 
    'subsample': 0.5, 
    'colsample_bytree': 0.9,
    'max_depth': 10, 
}

mae_global_min = 2510.5911186788753
DELTA = 0.0

big_iter = 0

current_vars=start_vars
all_vars = feats3 #maksymalny set

for variable in all_vars:

    if variable not in current_vars:
        print('Testuje: ' + variable)
        current_vars = np.sort([*current_vars, variable]) 
        print('len: ' + str(len(current_vars)))
        
        mae, r2, model, model_cl, learning_curve_plot = mozo2.train_and_submit(train_70, train_30, total.loc[total['price_value'].isna(),], 
                     current_vars, global_min, 
                     xgb.XGBRegressor, params, digitize=None, subfolder='XGBRegressor_forward_add',
                     file_sufix = 'backward_1_zm', opis='start=2604.46495618895, delta', 
                     learning_curve = False, 
                     add_model_column_min = -1, total = total, 
                     save_min=mae_global_min, kaggle_min=-1)

        if mae < mae_global_min + DELTA:
            if (mae < mae_global_min):
                mae_global_min = mae
                print('Improvement: ' + variable)
            else:
                print('Mutation: ' + variable)

        ### FORWARD nie usuweajacy dodanej cechy: 
#         current_vars = start_vars
        
        print('=============================================' + str(mae_global_min)+ '=============================================')

print('END')
# Out:
# Testuje: created_at_unix
# len: 53
# mea: 2715.628134475475
# r2: 0.9781342761499817
# =============================================2510.5911186788753=============================================
# Testuje: created_at_unix_na_mean
# len: 54
# mea: 2636.182400381012
# r2: 0.9791912054655381
# =============================================2510.5911186788753=============================================
# Testuje: encoded_param_kolor_2
# len: 55
# mea: 2568.1544363864396
# r2: 0.9790435043815604
# =============================================2510.5911186788753=============================================
# Testuje: encoded_param_skrzynia_biegów_2
# len: 56
# mea: 2714.2350878482143
# r2: 0.9784806468675713
# =============================================2510.5911186788753=============================================
# Testuje: encoded_param_typ_2
# len: 57
# mea: 2707.6807769653697
# r2: 0.9784024004760374
# =============================================2510.5911186788753=============================================
# Testuje: encoded_seller_miasto_297
# len: 58
# mea: 2662.3654610556237
# r2: 0.9786802490849043
# =============================================2510.5911186788753=============================================
# Testuje: feature_alarm
# len: 59
# mea: 2644.623925032223
# r2: 0.9787820562107226
# =============================================2510.5911186788753=============================================
# Testuje: feature_alufelgi
# len: 60
# mea: 2606.3520700691156
# r2: 0.9792507303428779
# =============================================2510.5911186788753=============================================
# Testuje: feature_asr__kontrola_trakcji_
# len: 61
# mea: 2538.5922162925312
# r2: 0.9791447111783701
# =============================================2510.5911186788753=============================================
# Testuje: feature_asystent_pasa_ruchu
# len: 62
# mea: 2758.5497216689123
# r2: 0.9781507442285704
# =============================================2510.5911186788753=============================================
# Testuje: feature_bluetooth
# len: 63
# mea: 2616.3184929273875
# r2: 0.9785735387843691
# =============================================2510.5911186788753=============================================
# Testuje: feature_cd
# len: 64
# mea: 2675.1576989589826
# r2: 0.9782231265666851
# =============================================2510.5911186788753=============================================
# Testuje: feature_czujnik_martwego_pola
# len: 65
# mea: 2609.4946743654345
# r2: 0.9788953135473673
# =============================================2510.5911186788753=============================================
# Testuje: feature_czujnik_zmierzchu
# len: 66
# mea: 2676.79496065224
# r2: 0.978440516906961
# =============================================2510.5911186788753=============================================
# Testuje: feature_czujniki_parkowania_przednie
# len: 67
# mea: 2610.921818272704
# r2: 0.9792002072568935
# =============================================2510.5911186788753=============================================
# Testuje: feature_czujniki_parkowania_tylne
# len: 68
# mea: 2596.6691597058557
# r2: 0.9792379425405413
# =============================================2510.5911186788753=============================================
# Testuje: feature_dach_panoramiczny
# len: 69
# mea: 2677.501498356557
# r2: 0.9783396397213815
# =============================================2510.5911186788753=============================================
# Testuje: feature_elektrochromatyczne_lusterka_boczne
# len: 70
# mea: 2692.859667516751
# r2: 0.9782928612680808
# =============================================2510.5911186788753=============================================
# Testuje: feature_elektryczne_szyby_przednie
# len: 71
# mea: 2834.030422608805
# r2: 0.9782809044010006
# =============================================2510.5911186788753=============================================
# Testuje: feature_esp__stabilizacja_toru_jazdy_
# len: 72
# mea: 2733.7225294124923
# r2: 0.97837320121739
# =============================================2510.5911186788753=============================================
# Testuje: feature_gniazdo_aux
# len: 73
# mea: 2601.59004203278
# r2: 0.9792118993705552
# =============================================2510.5911186788753=============================================
# Testuje: feature_gniazdo_sd
# len: 74
# mea: 2613.6689350949528
# r2: 0.9789920606598541
# =============================================2510.5911186788753=============================================
# Testuje: feature_gniazdo_usb
# len: 75
# mea: 2788.624200256552
# r2: 0.9775568172840929
# =============================================2510.5911186788753=============================================
# Testuje: feature_hak
# len: 76
# mea: 2622.313269972948
# r2: 0.9786281828337724
# =============================================2510.5911186788753=============================================
# Testuje: feature_immobilizer
# len: 77
# mea: 2674.8302673720013
# r2: 0.9784255883829485
# =============================================2510.5911186788753=============================================
# Testuje: feature_isofix
# len: 78
# mea: 2808.278533245933
# r2: 0.9775541626136542
# =============================================2510.5911186788753=============================================
# Testuje: feature_kamera_cofania
# len: 79
# mea: 2662.340367496326
# r2: 0.9783314274041961
# =============================================2510.5911186788753=============================================
# Testuje: feature_klimatyzacja_automatyczna
# len: 80
# mea: 2784.6540637189073
# r2: 0.9783253508114017
# =============================================2510.5911186788753=============================================
# Testuje: feature_klimatyzacja_czterostrefowa
# len: 81
# mea: 2771.0979720565856
# r2: 0.9783261293796731
# =============================================2510.5911186788753=============================================
# Testuje: feature_klimatyzacja_dwustrefowa
# len: 82
# mea: 2654.0399947291485
# r2: 0.9787888380671842
# =============================================2510.5911186788753=============================================
# Testuje: feature_komputer_pokładowy
# len: 83
# mea: 2565.502316977137
# r2: 0.9791999658234383
# =============================================2510.5911186788753=============================================
# Testuje: feature_kurtyny_powietrzne
# len: 84
# mea: 2655.0992707312676
# r2: 0.9786781798357458
# =============================================2510.5911186788753=============================================
# Testuje: feature_podgrzewane_lusterka_boczne
# len: 85
# mea: 2730.635331265258
# r2: 0.9780190872062181
# =============================================2510.5911186788753=============================================
# Testuje: feature_podgrzewane_przednie_siedzenia
# len: 86
# mea: 2804.8638791933286
# r2: 0.9779625398538538
# =============================================2510.5911186788753=============================================
# Testuje: feature_poduszka_powietrzna_chroniąca_kolana
# len: 87
# mea: 2855.072481486607
# r2: 0.9766163673496211
# =============================================2510.5911186788753=============================================
# Testuje: feature_poduszka_powietrzna_pasażera
# len: 88
# mea: 2922.6625043824424
# r2: 0.9769792978335141
# =============================================2510.5911186788753=============================================
# Testuje: feature_radio_niefabryczne
# len: 89
# mea: 2738.652719799616
# r2: 0.9786570304506944
# =============================================2510.5911186788753=============================================
# Testuje: feature_relingi_dachowe
# len: 90
# mea: 2559.8822410220378
# r2: 0.9792461238117857
# =============================================2510.5911186788753=============================================
# Testuje: feature_system_start_stop
# len: 91
# mea: 2582.6808559805368
# r2: 0.9791019872626274
# =============================================2510.5911186788753=============================================
# Testuje: feature_szyberdach
# len: 92
# mea: 2590.78127230537
# r2: 0.9793170306776764
# =============================================2510.5911186788753=============================================
# Testuje: feature_tapicerka_welurowa
# len: 93
# mea: 2564.481712425375
# r2: 0.9792983773646904
# =============================================2510.5911186788753=============================================
# Testuje: feature_tempomat
# len: 94
# mea: 2739.93462751877
# r2: 0.9781204295155207
# =============================================2510.5911186788753=============================================
# Testuje: feature_tempomat_aktywny
# len: 95
# mea: 2788.575820141787
# r2: 0.9780485437217569
# =============================================2510.5911186788753=============================================
# Testuje: feature_tuner_tv
# len: 96
# mea: 2801.741583693139
# r2: 0.9781294388747623
# =============================================2510.5911186788753=============================================
# Testuje: feature_wspomaganie_kierownicy
# len: 97
# mea: 2546.8273579867096
# r2: 0.9796003552294705
# =============================================2510.5911186788753=============================================
# Testuje: feature_zmieniarka_cd
# len: 98
# mea: 2635.7390641032785
# r2: 0.9788599875018654
# =============================================2510.5911186788753=============================================
# Testuje: feature_łopatki_zmiany_biegów
# len: 99
# mea: 2565.9055946297135
# r2: 0.979367648015722
# =============================================2510.5911186788753=============================================
# Testuje: feature_światła_do_jazdy_dziennej
# len: 100
# mea: 2531.198594140638
# r2: 0.9793345176710848
# =============================================2510.5911186788753=============================================
# Testuje: latitude
# len: 101
# mea: 2725.650778119018
# r2: 0.9782077668738893
# =============================================2510.5911186788753=============================================
# Testuje: longitude
# len: 102
# mea: 2729.00529793967
# r2: 0.9784058009864005
# =============================================2510.5911186788753=============================================
# Testuje: model_RandomForestRegressor_7089_27166_feats2
# len: 103
# mea: 5451.371492057532
# r2: 0.9441738855765703
# =============================================2510.5911186788753=============================================
# Testuje: model_XGBRegressor_2608_37590_po_hiperopcie
# len: 104
# mea: 4503.436502535351
# r2: 0.9579438140097019
# =============================================2510.5911186788753=============================================
# Testuje: model_XGBRegressor_3422_09438_start_vars_train_100
# len: 105
# mea: 4559.299464930008
# r2: 0.9554729561372274
# =============================================2510.5911186788753=============================================
# Testuje: model_XGBRegressor_5856_36229_
# len: 106
# mea: 5969.646344474529
# r2: 0.9365753591016275
# =============================================2510.5911186788753=============================================
# Testuje: new_cat_seller_address
# len: 107
# mea: 5984.75974269027
# r2: 0.9364327539515661
# =============================================2510.5911186788753=============================================
# Testuje: new_param_kod_silnika_cat
# len: 108
# mea: 5972.403819079441
# r2: 0.9367971892434057
# =============================================2510.5911186788753=============================================
# Testuje: new_param_kolor_cat
# len: 109
# mea: 5967.811778600637
# r2: 0.9367208628493334
# =============================================2510.5911186788753=============================================
# Testuje: new_param_kraj_pochodzenia_cat
# len: 110
# mea: 5961.553728778817
# r2: 0.9370552771418729
# =============================================2510.5911186788753=============================================
# Testuje: new_param_liczba_pozostałych_rat_cat
# len: 111
# mea: 5900.417112175637
# r2: 0.9378458245094167
# =============================================2510.5911186788753=============================================
# Testuje: new_param_marka_pojazdu_cat
# len: 112
# mea: 5952.470752675024
# r2: 0.9371739272535887
# =============================================2510.5911186788753=============================================
# Testuje: new_param_miesięczna_rata_cat
# len: 113
# mea: 5912.766501656723
# r2: 0.9373636995475713
# =============================================2510.5911186788753=============================================
# Testuje: new_param_model_pojazdu_cat
# len: 114
# mea: 5953.234822504058
# r2: 0.9370985641182319
# =============================================2510.5911186788753=============================================
# Testuje: new_param_napęd_cat
# len: 115
# mea: 5908.116406752969
# r2: 0.9377125055914243
# =============================================2510.5911186788753=============================================
# Testuje: new_param_oferta_od_cat
# len: 116
# mea: 5977.345363011487
# r2: 0.93665187535581
# =============================================2510.5911186788753=============================================
# Testuje: new_param_opłata_początkowa_cat
# len: 117
# mea: 5884.033730714656
# r2: 0.9381889249905686
# =============================================2510.5911186788753=============================================
# Testuje: new_param_pierwsza_rejestracja_cat
# len: 118
# mea: 5967.124828139259
# r2: 0.9366536028560057
# =============================================2510.5911186788753=============================================
# Testuje: new_param_typ_cat
# len: 119
# mea: 5855.290780623239
# r2: 0.9389305911544371
# =============================================2510.5911186788753=============================================
# Testuje: new_param_vin_cat
# len: 120
# mea: 5979.970830240814
# r2: 0.9362763205266394
# =============================================2510.5911186788753=============================================
# Testuje: new_param_wartość_wykupu_cat
# len: 121
# mea: 5875.645501256183
# r2: 0.9384180240992978
# =============================================2510.5911186788753=============================================
# Testuje: new_seller_address_cat
# len: 122
# mea: 5965.110329088786
# r2: 0.9365217601078836
# =============================================2510.5911186788753=============================================
# Testuje: new_seller_name_cat
# len: 123
# mea: 5890.475870916756
# r2: 0.9381323652645277
# =============================================2510.5911186788753=============================================
# Testuje: new_vin_flex_fuel_cat
# len: 124
# mea: 5960.848760155651
# r2: 0.9366865099789261
# =============================================2510.5911186788753=============================================
# Testuje: new_vin_model_cat
# len: 125
# mea: 5895.569506101507
# r2: 0.9380010930419174
# =============================================2510.5911186788753=============================================
# Testuje: new_vin_plant_cat
# len: 126
# mea: 5964.662340951121
# r2: 0.936572359633022
# =============================================2510.5911186788753=============================================
# Testuje: new_vin_where_cat
# len: 127
# mea: 5898.395658801888
# r2: 0.9379575678863674
# =============================================2510.5911186788753=============================================
# Testuje: ogloszenie_dni_wisi
# len: 128
# mea: 5943.851669268215
# r2: 0.937168633261261
# =============================================2510.5911186788753=============================================
# Testuje: ogloszenie_dzien_tyg
# len: 129
# mea: 5901.611788426171
# r2: 0.9380086586774725
# =============================================2510.5911186788753=============================================
# Testuje: ogloszenie_godzina
# len: 130
# mea: 5953.61662027954
# r2: 0.9369355980802052
# =============================================2510.5911186788753=============================================
# Testuje: ogloszenie_miesiac
# len: 131
# mea: 5942.365369404963
# r2: 0.9375279549765686
# =============================================2510.5911186788753=============================================
# Testuje: ogloszenie_rok
# len: 132
# mea: 5964.895874641947
# r2: 0.9370538119001305
# =============================================2510.5911186788753=============================================
# Testuje: param_akryl__niemetalizowany_
# len: 133
# mea: 5982.547009334579
# r2: 0.9364463405618474
# =============================================2510.5911186788753=============================================
# Testuje: param_emisja_co2_2
# len: 134
# mea: 5951.065925516256
# r2: 0.937372204134093
# =============================================2510.5911186788753=============================================
# Testuje: param_homologacja_ciężarowa
# len: 135
# mea: 5975.339162455523
# r2: 0.9367839001499385
# =============================================2510.5911186788753=============================================
# Testuje: param_ile_lat_temu_produkcja
# len: 136
# mea: 5963.1635522850665
# r2: 0.93704240660823
# =============================================2510.5911186788753=============================================
# Testuje: param_kierownica_po_prawej__anglik_
# len: 137
# mea: 5921.0950488090975
# r2: 0.9378056724386924
# =============================================2510.5911186788753=============================================
# Testuje: param_leasing
# len: 138
# mea: 5957.005459907477
# r2: 0.9372340627832142
# =============================================2510.5911186788753=============================================
# Testuje: param_liczba_drzwi
# len: 139
# mea: 5915.873201264889
# r2: 0.9379171700028499
# =============================================2510.5911186788753=============================================
# Testuje: param_matowy
# len: 140
# mea: 5960.005069438365
# r2: 0.9371451789515509
# =============================================2510.5911186788753=============================================
# Testuje: param_metalik
# len: 141
# mea: 5912.255940495574
# r2: 0.9380136293363925
# =============================================2510.5911186788753=============================================
# Testuje: param_moc
# len: 142
# mea: 5949.611107200927
# r2: 0.9375537861776542
# =============================================2510.5911186788753=============================================
# Testuje: param_możliwość_finansowania
# len: 143
# mea: 5920.4382372184145
# r2: 0.9376359385655472
# =============================================2510.5911186788753=============================================
# Testuje: param_opłata_początkowa_2
# len: 144
# mea: 5933.197177779537
# r2: 0.9376742908773201
# =============================================2510.5911186788753=============================================
# Testuje: param_perłowy
# len: 145
# mea: 5914.486103783845
# r2: 0.9376858960264817
# =============================================2510.5911186788753=============================================
# Testuje: param_pierwsza_rejestracja_poprzedni_rok
# len: 146
# mea: 5950.061059829132
# r2: 0.9369670686083721
# =============================================2510.5911186788753=============================================
# Testuje: param_pierwsza_rejestracja_ten_rok
# len: 147
# mea: 5925.9094382937765
# r2: 0.9375406287628923
# =============================================2510.5911186788753=============================================
# Testuje: param_pierwszy_właściciel
# len: 148
# mea: 5941.149073886556
# r2: 0.9372547036973579
# =============================================2510.5911186788753=============================================
# Testuje: param_pojemność_skokowa
# len: 149
# mea: 5925.42695766845
# r2: 0.9376788846882149
# =============================================2510.5911186788753=============================================
# Testuje: param_rok_produkcji
# len: 150
# mea: 5951.747605457762
# r2: 0.9369533578742426
# =============================================2510.5911186788753=============================================
# Testuje: param_rok_produkcji_10_lat
# len: 151
# mea: 5949.478168277439
# r2: 0.9373150155399761
# =============================================2510.5911186788753=============================================
# Testuje: param_rok_produkcji_poprzedni_rok
# len: 152
# mea: 5958.178903417422
# r2: 0.9369789020572754
# =============================================2510.5911186788753=============================================
# Testuje: param_rok_produkcji_ten_rok
# len: 153
# mea: 5949.296869098337
# r2: 0.9372954597454066
# =============================================2510.5911186788753=============================================
# Testuje: param_tuning
# len: 154
# mea: 5963.264344005015
# r2: 0.9367105134192182
# =============================================2510.5911186788753=============================================
# Testuje: param_uszkodzony
# len: 155
# mea: 5952.234808167855
# r2: 0.9372142008162767
# =============================================2510.5911186788753=============================================
# Testuje: param_vat_discount
# len: 156
# mea: 5939.954652865868
# r2: 0.9373264131749559
# =============================================2510.5911186788753=============================================
# Testuje: param_vat_free
# len: 157
# mea: 5956.57388680915
# r2: 0.937027340071784
# =============================================2510.5911186788753=============================================
# Testuje: param_vat_marża
# len: 158
# mea: 5906.230451762935
# r2: 0.9382324724557395
# =============================================2510.5911186788753=============================================
# Testuje: param_wartość_wykupu_2
# len: 159
# mea: 5943.360204152273
# r2: 0.9373470362602917
# =============================================2510.5911186788753=============================================
# Testuje: param_zarejestrowany_jako_zabytek
# len: 160
# mea: 5937.773302453838
# r2: 0.9377821989817295
# =============================================2510.5911186788753=============================================
# Testuje: param_zarejestrowany_w_polsce
# len: 161
# mea: 5948.732908618536
# r2: 0.9370012725855033
# =============================================2510.5911186788753=============================================
# Testuje: pln_to_eur
# len: 162
# mea: 5923.788008919535
# r2: 0.9379304825448823
# =============================================2510.5911186788753=============================================
# Testuje: price_currency_pln
# len: 163
# mea: 5941.785604860175
# r2: 0.9373403509523806
# =============================================2510.5911186788753=============================================
# END

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
kaggle_api = KaggleApi()
kaggle_api.authenticate()

leaderboard = kaggle_api.competition_view_leaderboard('dw-car-price-prediction')
print(pd.DataFrame(leaderboard['submissions'])[['teamName', 'submissionDate', 'score']].head())
# Out:
#           teamName                submissionDate       score
# 0       adamskorek  2020-10-31T23:26:16.9833333Z  5156.58793
# 1           pelele  2020-10-31T19:46:31.2633333Z  5369.00636
# 2             mozo  2020-10-30T16:38:46.7333333Z  5466.72056
# 3  Adrian Mich***i       2020-10-31T12:30:08.39Z  5578.96222
# 4   Remek Półtorak  2020-10-31T19:09:20.1866667Z  5581.85197

# %%
# model = RandomForestRegressor(n_estimators=50, max_depth=7).fit(X_sub_train, y_sub_train) 
import eli5
from eli5.sklearn import PermutationImportance
from sklearn.svm import SVC


# perm = PermutationImportance(model).fit(X_sub_test, y_sub_test) 
eli5.show_weights(perm, feature_names=random_feats, top=50)
# Out:
# /home/conda/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/conda/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-2e8c5dcaa199> in <module>
#       6
#       7 # perm = PermutationImportance(model).fit(X_sub_test, y_sub_test)
# ----> 8 eli5.show_weights(perm, feature_names=random_feats, top=50)
#
# NameError: name 'perm' is not defined

# %% [markdown]
# save_model(file_sufix='test', subfolder='', test = total.loc[total['price_value'].isna()],
#                feats=current_vars, global_min=global_min, model=model, shift = 0, digitize=False, mae=mae, r2=r2,
#                details='test zapisu', learning_curve_plot=None, hist_plt=None, kaggle=None)
